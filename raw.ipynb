# %%
from rawkit.raw import Raw
from rawkit.options import WhiteBalance
import numpy as np
from mpldatacursor import datacursor
from scipy import ndimage
import warnings,glob
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    # %matplotlib nbagg
    import matplotlib.pyplot as plt
    import matplotlib

# %%
with Raw(filename='/Users/rein/Desktop/full_00015_iso3200_shutter1s.cr2') as raw:
    data, cdesc = raw.bayer_data(include_margin=False)
# Out:
# /Users/rein/git/rebound/venv/lib/python3.5/site-packages/rawkit/raw.py:269: UserWarning: The image is flipped.
#   "The image is flipped."

# %%
len(data[0])
# Out:
# 5202

# %%
dn = np.array(data)

# %%
dn.shape
# Out:
# (3465, 5202)

# %%
fig, ax = plt.subplots(figsize=(7,5))
ax.imshow(dn[::2,1::2], cmap="hot")
# Out:
# <img src="data:image/png;base64,..." width="700">
